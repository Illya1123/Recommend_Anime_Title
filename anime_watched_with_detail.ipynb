# %%
import pandas as pd
import os

# %%
anime_watched = pd.read_csv('./data/cleaned/anime_watched_data.csv')
anime_data = pd.read_csv('./data/cleaned/anime_data_cleaned.csv')

anime_watched.head()
# Out:
#    user_id                                     titles_watched
# 0        1  Tenchi Muyou! Manatsu no Eve, Tây Hành Kỷ: Ám ...
# 1        2  Yu☆Gi☆Oh!: Sevens, Brave Story, Mecha-ude (TV)...
# 2        3  Re:Zero kara Hajimeru Isekai Seikatsu, GetBack...
# 3        4  One Piece Film: Red, Horimiya Live Action, Gun...
# 4        5  Những Đứa Trẻ Đến Từ Thế Giới Khác OVA, Gankut...

# %%
anime_data.head()
# Out:
#                                             title  \
# 0                           5-toubun no Hanayome*
# 1                Overlord Movie 3: Sei Oukoku-hen
# 2             Digimon Adventure 02: The Beginning
# 3  Tengen Toppa Gurren Lagann Movie 1: Gurren-hen
# 4                     Yowamushi Pedal: Spare Bike
#
#                                                 link  \
# 0  https://animevietsub.page/phim/5-toubun-no-han...
# 1  https://animevietsub.page/phim/overlord-movie-...
# 2  https://animevietsub.page/phim/digimon-adventu...
# 3  https://animevietsub.page/phim/tengen-toppa-gu...
# 4  https://animevietsub.page/phim/yowamushi-pedal...
#
#                                                image episode  \
# 0  https://cdn.animevietsub.page/data/poster/2024...       1
# 1  https://cdn.animevietsub.page/data/poster/2024...       1
# 2  https://cdn.animevietsub.page/data/poster/2024...       1
# 3  https://cdn.animevietsub.page/data/poster/2024...       1
# 4  https://cdn.animevietsub.page/data/poster/2024...       1
#
#                                              rating   views  quality  year  \
# 0  9.6 trong số 10 dựa trên 301 thành viên đánh giá  235236       HD  2024
# 1  9.4 trong số 10 dựa trên 115 thành viên đánh giá  687666      CAM  2024
# 2    7.3 trong số 10 dựa trên 3 thành viên đánh giá   27447       HD  2023
# 3      9 trong số 10 dựa trên 9 thành viên đánh giá   37285  Full HD  2008
# 4   7.5 trong số 10 dựa trên 11 thành viên đánh giá   15265  Full HD  2016
#
#                                       genres  \
# 0    Shounen, School, Romance, Harem, Comedy
# 1          Fantasy, Adventure, Magic, Action
# 2  Fantasy, Drama, Comedy, Adventure, Action
# 3                             Sci-Fi, Action
# 4             Shounen, Sports, Drama, Action
#
#                                          description   season     type  rate  \
# 0  Chuyến đi tuần trăng mật của Fuutarou Uesugi v...  Mùa thu  phim lẻ   9.6
# 1  Vương quốc thiêng liêng đã trải qua nhiều năm ...  Mùa thu  phim lẻ   9.4
# 2  Hai năm sau trận chiến với Eosmon, Davis Motom...  Mùa thu  phim lẻ   7.3
# 3  Studio hoạt hình Gainax đã giới thiệu một tran...  Mùa thu  phim lẻ   9.0
# 4  Anime chuyển thể từ manga ngoại truyện cùng tê...  Mùa thu  phim lẻ   7.5
#
#    nums_of_vote
# 0           301
# 1           115
# 2             3
# 3             9
# 4            11

# %%
# Tách các title trong cột titles_watched của anime_watched_data
anime_watched['titles_watched'] = anime_watched['titles_watched'].apply(lambda x: x.split(', '))

# Mở rộng data anime_watched_data để mỗi hàng là một user và một title mà họ đã xem
anime_watched_expanded = anime_watched.explode('titles_watched').reset_index(drop=True)

# %%
# Kết hợp dữ liệu anime_watched_expanded với anime_data_cleaned dựa trên title
merged_data = pd.merge(anime_watched_expanded, anime_data, left_on='titles_watched', right_on='title', how='left')

# %%
cleaned_data = merged_data.dropna()

# %%
print(merged_data[['user_id', 'titles_watched', 'link', 'image', 'episode', 'rating', 'views', 'quality', 'year', 'genres', 'description', 'season', 'type', 'rate', 'nums_of_vote']])
# Out:
#         user_id                                  titles_watched  \
# 0             1                    Tenchi Muyou! Manatsu no Eve
# 1             1                    Tây Hành Kỷ: Ám Ảnh Ma Thành
# 2             1  Aikatsu! 10th Story: Mirai e no Starway (2023)
# 3             1              Cardfight!! Vanguard: Shinemon-hen
# 4             1                              Tuyết Ưng Lĩnh Chủ
# ...         ...                                             ...
# 105755     9999                       Ta Có Thể Giác Ngộ Vô Hạn
# 105756    10000                                       Sky Girls
# 105757    10000                                       Teekyuu 2
# 105758    10000                                     Dennou Coil
# 105759    10000                           Học Viện Đỏ Đen Mùa 2
#
#                                                      link  \
# 0       https://animevietsub.page/phim/tenchi-muyou-ma...
# 1       https://animevietsub.page/phim/tay-hanh-ky-am-...
# 2       https://animevietsub.page/phim/aikatsu-10th-st...
# 3       https://animevietsub.page/phim/cardfight-vangu...
# 4       https://animevietsub.page/phim/tuyet-ung-linh-...
# ...                                                   ...
# 105755  https://animevietsub.page/phim/ta-co-the-giac-...
# 105756     https://animevietsub.page/phim/sky-girls-a281/
# 105757    https://animevietsub.page/phim/teekyuu-2-a2529/
# 105758   https://animevietsub.page/phim/dennou-coil-a730/
# 105759  https://animevietsub.page/phim/hoc-vien-do-den...
#
#                                                     image   episode  \
# 0       https://cdn.animevietsub.page/data/poster/2017...         1
# 1       https://cdn.animevietsub.page/data/poster/2023...         1
# 2       https://cdn.animevietsub.page/data/poster/2023...         1
# 3       https://cdn.animevietsub.page/data/poster/2020...  HOÀN TẤT
# 4       https://cdn.animevietsub.page/data/poster/2018...  HOÀN TẤT
# ...                                                   ...       ...
# 105755  https://cdn.animevietsub.page/data/poster/2024...    TẬP 28
# 105756  https://cdn.animevietsub.page/data/poster/2017...  HOÀN TẤT
# 105757  https://cdn.animevietsub.page/data/poster/2017...  HOÀN TẤT
# 105758  https://cdn.animevietsub.page/data/poster/2017...  HOÀN TẤT
# 105759  https://cdn.animevietsub.page/data/poster/2018...  HOÀN TẤT
#
#                                                   rating    views quality  \
# 0          10 trong số 10 dựa trên 1 thành viên đánh giá    19564      SD
# 1           7 trong số 10 dựa trên 9 thành viên đánh giá    61929      HD
# 2        9.4 trong số 10 dựa trên 28 thành viên đánh giá   107615      HD
# 3           4 trong số 10 dựa trên 3 thành viên đánh giá    27261      HD
# 4        8.1 trong số 10 dựa trên 25 thành viên đánh giá   462809      HD
# ...                                                  ...      ...     ...
# 105755   7.5 trong số 10 dựa trên 13 thành viên đánh giá   195009      HD
# 105756    8.2 trong số 10 dựa trên 5 thành viên đánh giá    36711      HD
# 105757      7 trong số 10 dựa trên 3 thành viên đánh giá    20143      HD
# 105758    7.1 trong số 10 dựa trên 7 thành viên đánh giá    29993      HD
# 105759  9.5 trong số 10 dựa trên 106 thành viên đánh giá  1183421      HD
#
#         year                                             genres  \
# 0       1997             Shounen, Sci-Fi, Space, Comedy, Action
# 1       2023                Cartoon, Fantasy, Adventure, Action
# 2       2023                                              Music
# 3       2019                              Shounen, Game, Action
# 4       2018                                            Cartoon
# ...      ...                                                ...
# 105755  2024                                            Cartoon
# 105756  2007                            Sci-Fi, Military, Mecha
# 105757  2013                    Shounen, School, Sports, Comedy
# 105758  2007          Sci-Fi, Drama, Comedy, Adventure, Mystery
# 105759  2019  Shounen, School, Psychological, Game, Drama, M...
#
#                                               description    season     type  \
# 0                                           Đang cập nhật    Mùa hè  phim lẻ
# 1       Ma Anh chủ nhân nhân của Ám Ảnh ma thành vì mu...  Mùa xuân  phim lẻ
# 2       Aikatsu mới! phim lấy bối cảnh năm 2023 sau Ai...  Mùa đông  phim lẻ
# 3       Đây là câu chuyện về "Shinemon Nitta", người q...  Mùa đông  phim bộ
# 4       Bước chân của người khổng lồ sống giữa dòng du...  Mùa xuân  phim bộ
# ...                                                   ...       ...      ...
# 105755  Nhờ có sự dũng cảm hơn người, khí phách anh hù...   Mùa thu  phim bộ
# 105756  Câu truyện nói về thời kì lần thứ 3 con người ...    Mùa hè  phim bộ
# 105757  Một đống chuyện hài về những cô gái trong CLB ...    Mùa hè  phim bộ
# 105758  Trong tương lai, công nghệ phát triển vượt bậc...  Mùa xuân  phim bộ
# 105759                            Phần hai của Kakegurui.  Mùa xuân  phim bộ
#
#         rate  nums_of_vote
# 0       10.0             1
# 1        7.0             9
# 2        9.4            28
# 3        4.0             3
# 4        8.1            25
# ...      ...           ...
# 105755   7.5            13
# 105756   8.2             5
# 105757   7.0             3
# 105758   7.1             7
# 105759   9.5           106
#
# [105760 rows x 15 columns]

# %%
output_dir = 'data/proceeded'

# %%
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
output_path = os.path.join(output_dir, 'anime_watched_with_details.csv')
merged_data[['user_id', 'titles_watched', 'link', 'image', 'episode', 'rating', 'views', 'quality', 'year', 'genres', 'description', 'season', 'type', 'rate', 'nums_of_vote']].to_csv(output_path, index=False)

print(f"File CSV đã được xuất ra tại {output_path}")
# Out:
# File CSV đã được xuất ra tại data/proceeded\anime_watched_with_details.csv
